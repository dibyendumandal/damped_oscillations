# %% [markdown]
# QUANDL key - FUxAWpxjKyz4RUjF7EkJ

# %%
import pandas as pd

# %%
apple = pd.read_csv('WIKI-AAPL.csv', index_col=0, parse_dates=True)
apple.head()
# Out:
#               Open    High     Low    Close      Volume  Ex-Dividend  \
# Date
# 2018-03-27  173.68  175.15  166.92  168.340  38962839.0          0.0
# 2018-03-26  168.07  173.10  166.44  172.770  36272617.0          0.0
# 2018-03-23  168.39  169.92  164.94  164.940  40248954.0          0.0
# 2018-03-22  170.00  172.68  168.60  168.845  41051076.0          0.0
# 2018-03-21  175.04  175.09  171.26  171.270  35247358.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2018-03-27          1.0     173.68     175.15    166.92     168.340
# 2018-03-26          1.0     168.07     173.10    166.44     172.770
# 2018-03-23          1.0     168.39     169.92    164.94     164.940
# 2018-03-22          1.0     170.00     172.68    168.60     168.845
# 2018-03-21          1.0     175.04     175.09    171.26     171.270
#
#             Adj. Volume
# Date
# 2018-03-27   38962839.0
# 2018-03-26   36272617.0
# 2018-03-23   40248954.0
# ...

# %%
amazon = pd.read_csv('WIKI-AMZN.csv', index_col=0, parse_dates=True)
facebook = pd.read_csv('WIKI-FB.csv', index_col=0, parse_dates=True)
google = pd.read_csv('WIKI-GOOG.csv', index_col=0, parse_dates=True)
walmart = pd.read_csv('WIKI-WMT.csv', index_col=0, parse_dates=True)

# %%
apple_short = apple.iloc[:, :4]
apple_short.head()
# Out:
#               Open    High     Low    Close
# Date
# 2018-03-27  173.68  175.15  166.92  168.340
# 2018-03-26  168.07  173.10  166.44  172.770
# 2018-03-23  168.39  169.92  164.94  164.940
# 2018-03-22  170.00  172.68  168.60  168.845
# 2018-03-21  175.04  175.09  171.26  171.270

# %%
apple_short.to_csv('apple_short.csv')

# %%
df = pd.read_csv('apple_short.csv', index_col=0, parse_dates=True)
df.head()
# Out:
#               Open    High     Low    Close
# Date
# 2018-03-27  173.68  175.15  166.92  168.340
# 2018-03-26  168.07  173.10  166.44  172.770
# 2018-03-23  168.39  169.92  164.94  164.940
# 2018-03-22  170.00  172.68  168.60  168.845
# 2018-03-21  175.04  175.09  171.26  171.270

# %%
df.shape
# Out:
# (9400, 4)

# %%
amazon_short = amazon.iloc[:, :4]
facebook_short = facebook.iloc[:, :4]
google_short = google.iloc[:, :4]
walmart_short = walmart.iloc[:, :4]

# %%
amazon_short.to_csv('amazon_short.csv')
facebook_short.to_csv('facebook_short.csv')
google_short.to_csv('google_short.csv')
walmart_short.to_csv('walmart_short.csv')

# %%
% matplotlib inline
apple_short.plot()
plt.title('Stock');

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(apple_short.iloc[:, 1], label='Apple')
plt.plot(amazon_short.iloc[:, 1], label='Amazon')
plt.xlabel('Date')
plt.ylabel('Stock price')
plt.legend();

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1c8914a9-07e4-4d52-8a67-294a960bf400">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(x_axis_type='datetime')
p.line(apple_short.index, apple_short.Low, color='blue', legend='Low')
p.line(apple_short.index, apple_short.Close, color='red', legend='Close')
show(p)
# Out:
#   <div class="bk-root" id="7533cdc5-1835-4a63-adb2-b2a696be337d"></div>

# %%
if True: print(5)
# Out:
# 5
